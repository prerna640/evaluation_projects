# %%
#importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn import metrics
warnings.filterwarnings('ignore')

# %%
#importing dataset

# %%
import pandas as pd
df=pd.read_excel("E:\covid1.xlsx")

# %%
#applying eda

# %%
df.shape
# Out:
# (5961, 7)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
sns.set_context('paper', font_scale=2.0)

# %%
df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['Qualification'].unique()
# Out:
# array(['BHMS, MD - Homeopathy', 'BAMS, MD - Ayurveda Medicine',
#        'MBBS, MS - Otorhinolaryngology', ...,
#        'MD - Dermatology , Venereology & Leprosy, MBBS, Fellowship In Dermatosurgery',
#        'BDS, certification in smile designing',
#        'MD - Homeopathy, Post Graduate Diploma in Healthcare Management(PGDHM), DHMS (Diploma in Homeopathic Medicine and Surgery)'],
#       dtype=object)

# %%
df['Experience'].unique()
# Out:
# array(['24 years experience', '12 years experience', '9 years experience',
#        '20 years experience', '8 years experience', '42 years experience',
#        '10 years experience', '14 years experience',
#        '23 years experience', '5 years experience', '7 years experience',
#        '21 years experience', '19 years experience',
#        '41 years experience', '31 years experience',
#        '25 years experience', '16 years experience',
#        '15 years experience', '11 years experience',
#        '22 years experience', '38 years experience', '6 years experience',
#        '36 years experience', '13 years experience',
#        '18 years experience', '46 years experience',
#        '40 years experience', '49 years experience',
#        '33 years experience', '0 years experience', '27 years experience',
#        '30 years experience', '52 years experience',
#        '60 years experience', '26 years experience',
#        '35 years experience', '34 years experience',
# ...

# %%
df['Rating'].unique()
# Out:
# array(['100%', '98%', nan, '99%', '79%', '95%', '97%', '94%', '88%',
#        '90%', '80%', '93%', '36%', '78%', '87%', '96%', '82%', '89%',
#        '74%', '86%', '92%', '83%', '76%', '85%', '56%', '91%', '68%',
#        '60%', '75%', '69%', '73%', '67%', '77%', '33%', '55%', '71%',
#        '84%', '45%', '63%', '72%', '81%', '62%', '57%', '7%', '48%',
#        '40%', '70%', '64%', '65%', '47%', '58%', '53%'], dtype=object)

# %%
df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %%
df['Lat'].fillna(df['Lat'].mean(),inplace=True)

# %%
df.isnull().sum()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
#df['city']=le.fit_transform(df['city'])

list1=['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
       'Miscellaneous_Info', 'Fees']
for val in list1:
   df[val]=le.fit_transform(df[val].astype(str))

# %%
df.isnull().sum()
# Out:
# Qualification         0
# Experience            0
# Rating                0
# Place                 0
# Profile               0
# Miscellaneous_Info    0
# Fees                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Qualification         int32
# Experience            int32
# Rating                int32
# Place                 int32
# Profile               int32
# Miscellaneous_Info    int32
# Fees                  int32
# dtype: object

# %%
#checking correlation with the target variable
plt.figure(figsize=(10,5))
df.drop('Fees',axis=1).corrwith(df['Fees']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correlation with target variable")
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %%
#checking correlation with the target variable
plt.figure(figsize=(10,8))
df.drop('Rating',axis=1).corrwith(df['Rating']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correlation with target variable")
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %%
#checking correlation with the target variable
plt.figure(figsize=(20,6))
df.drop('Experience',axis=1).corrwith(df['Experience']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("correlation with target variable")
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %%
for col in df.describe().columns:
    sns.distplot(df[col],color='r')
    plt.show()

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
#checking skewness

# %%
df.skew()
# Out:
# Qualification         0.239720
# Experience            0.823531
# Rating               -1.956421
# Place                 0.054543
# Profile               0.108803
# Miscellaneous_Info   -0.912485
# Fees                  0.295487
# dtype: float64

# %%
df.head()
# Out:
#    Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  Fees
# 0            401          16       0    222        5                 336     1
# 1             73           3      44    852        0                 472    16
# 2           1135          63      47    398        3                2215    15
# 3            464           3      47    645        0                 774    10
# 4             10          12       0    265        0                1702    10

# %%
df.dtypes
# Out:
# Qualification         int32
# Experience            int32
# Rating                int32
# Place                 int32
# Profile               int32
# Miscellaneous_Info    int32
# Fees                  int32
# dtype: object

# %%
# UNIVARIATE AND BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='Qualification',data=df)

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='Experience',data=df)

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='Rating',data=df)

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2F101BF10>,
# ...
#       dtype=object)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(20,8))
sns.jointplot(x='Fees',y='Experience',data=df,kind='reg')

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(20,10))
sns.jointplot(x='Fees',y='Qualification',data=df,kind='reg')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,4))
sns.jointplot(x='Fees',y='Rating',data=df,kind='reg')

# %%
df['Rating'].values.max()
# Out:
# 51

# %%
plt.figure(figsize=(20,4))
sns.barplot(x='Fees',y='Rating', data=df)
sns.set_context('paper', font_scale=0.5)

# %%
plt.figure(figsize=(20,3))
sns.barplot(x='Fees',y='Qualification', data=df)
sns.set_context('paper', font_scale=2)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Fees',y='Experience', data=df)
sns.set_context('paper', font_scale=1.6)

# %%
df.head()
# Out:
#    Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  Fees
# 0            401          16       0    222        5                 336     1
# 1             73           3      44    852        0                 472    16
# 2           1135          63      47    398        3                2215    15
# 3            464           3      47    645        0                 774    10
# 4             10          12       0    265        0                1702    10

# %%
plt.figure(figsize=(29,3))
sns.countplot(x='Experience',data=df)
sns.set_context('paper', font_scale=1.9)

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
df=df.corr()
df
# Out:
#                     Qualification  Experience    Rating     Place   Profile  \
# Qualification            1.000000    0.003325 -0.000404  0.012617  0.393123
# Experience               0.003325    1.000000 -0.024300 -0.003173 -0.032711
# Rating                  -0.000404   -0.024300  1.000000  0.009087  0.047330
# Place                    0.012617   -0.003173  0.009087  1.000000  0.007612
# Profile                  0.393123   -0.032711  0.047330  0.007612  1.000000
# Miscellaneous_Info       0.080520    0.035302  0.104518  0.007439  0.165591
# Fees                     0.215996   -0.049660 -0.054291 -0.055699  0.126876
#
#                     Miscellaneous_Info      Fees
# Qualification                 0.080520  0.215996
# Experience                    0.035302 -0.049660
# Rating                        0.104518 -0.054291
# Place                         0.007439 -0.055699
# Profile                       0.165591  0.126876
# Miscellaneous_Info            1.000000 -0.000741
# ...

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info', 'Fees'],
#       dtype='object')

# %%
#splitting the trining set and test set

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1.00000000e+00,  3.32482875e-03, -4.03863801e-04,
#          1.26172394e-02,  3.93123491e-01,  8.05195600e-02],
#        [ 3.32482875e-03,  1.00000000e+00, -2.43000684e-02,
#         -3.17348751e-03, -3.27107202e-02,  3.53023705e-02],
#        [-4.03863801e-04, -2.43000684e-02,  1.00000000e+00,
#          9.08688290e-03,  4.73300494e-02,  1.04518223e-01],
#        [ 1.26172394e-02, -3.17348751e-03,  9.08688290e-03,
#          1.00000000e+00,  7.61215288e-03,  7.43920803e-03],
#        [ 3.93123491e-01, -3.27107202e-02,  4.73300494e-02,
#          7.61215288e-03,  1.00000000e+00,  1.65591127e-01],
#        [ 8.05195600e-02,  3.53023705e-02,  1.04518223e-01,
#          7.43920803e-03,  1.65591127e-01,  1.00000000e+00],
#        [ 2.15995736e-01, -4.96600886e-02, -5.42912716e-02,
#         -5.56994606e-02,  1.26876183e-01, -7.41171923e-04]])

# %%
y
# Out:
# array([ 2.15995736e-01, -4.96600886e-02, -5.42912716e-02, -5.56994606e-02,
#         1.26876183e-01, -7.41171923e-04,  1.00000000e+00])

# %%
# THINK WHICH MODEL CAN BE APPLIED OVER THE DATASET

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.50, random_state = 0)

# %%
y_test.shape
# Out:
# (4,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
df.tail()
# Out:
#                     Qualification  Experience    Rating     Place   Profile  \
# Rating                  -0.000404   -0.024300  1.000000  0.009087  0.047330
# Place                    0.012617   -0.003173  0.009087  1.000000  0.007612
# Profile                  0.393123   -0.032711  0.047330  0.007612  1.000000
# Miscellaneous_Info       0.080520    0.035302  0.104518  0.007439  0.165591
# Fees                     0.215996   -0.049660 -0.054291 -0.055699  0.126876
#
#                     Miscellaneous_Info      Fees
# Rating                        0.104518 -0.054291
# Place                         0.007439 -0.055699
# Profile                       0.165591  0.126876
# Miscellaneous_Info            1.000000 -0.000741
# Fees                         -0.000741  1.000000

# %%
y_test
# Out:
# array([ 1.        , -0.05429127, -0.04966009, -0.05569946])

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
pred=regressor.predict(X_test)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.5274976830528921
# MSE: 0.5565078591268517
# RMSE: 0.7459945436307506

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
pred=regressor.predict(X_test)

# %%
# FIND THE INPUT FEATURES AND TARGET VARIABLES

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 2.712311885217581
# MSE: 20.063823472370455
# RMSE: 4.479265952404529

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(X_train,y_train)
pred=rdr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.34492221990898775
# MSE: 0.2190966591894694
# RMSE: 0.46807762090220617

# %%
plt.scatter(x=y_test,y=pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#saving this model 
import joblib

#saving the model as a pickle in a file
joblib.dump(rdr,'space.plk')
